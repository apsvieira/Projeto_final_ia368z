# %%
import os
import time
import sys
import numpy as np

import torch
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data

import torchvision
import torchvision.transforms as transforms
import torchvision.utils as vutils
import torch.nn.functional as F
from torch.autograd import Variable

# %% [markdown]
# ### System properties and libs currently in use
# - We have developed using python 3.5.x, pytorch 0.2.1
# - No significant attention was given to backwards compatibility
# - Or forwards, for that matter.

# %%
print('__Python VERSION:', sys.version)
print('__pyTorch VERSION:', torch.__version__)
print('__CUDA VERSION')
print('__CUDNN VERSION:', torch.backends.cudnn.version())
print('__Number CUDA Devices:', torch.cuda.device_count())
print('__Devices')
print('Active CUDA Device: GPU', torch.cuda.current_device())
# Out:
# __Python VERSION: 3.5.3 |Anaconda 4.4.0 (64-bit)| (default, Mar  6 2017, 11:58:13)
# [GCC 4.4.7 20120313 (Red Hat 4.4.7-1)]
# __pyTorch VERSION: 0.2.0_4
# __CUDA VERSION
# __CUDNN VERSION: 6021
# __Number CUDA Devices: 1
# __Devices
# Active CUDA Device: GPU 0

# %% [markdown]
# ### Utilities
# - Saving images and models

# %%
def save_images(netG, fixed_noise, outputDir,epoch):
    '''
    Generates a batch of images from the given 'noise'.
    Saves 64 of the generated samples to 'outputDir' system path.
    Inputs are the network (netG), a 'noise' input, system path to which images will be saved (outputDir) and current 'epoch'.
    '''
    noise = Variable(fixed_noise)
    netG.eval()
    fake = netG(noise)
    netG.train()
    vutils.save_image(fake.data[0:64,:,:,:],'%s/fake_samples_epoch_%03d.png' % (outputDir, epoch), nrow=8)

def save_models(netG, netD, outputDir, epoch):
    '''
    Saves model state dictionary for generator and discriminator networks.
    Inputs are the networks (netG, netD), the system path in which to save(outputDir) and the current 'epoch'.
    '''
    torch.save(netG.state_dict(), '%s/netG_epoch_%d.pth' % (outputDir, epoch))
    torch.save(netD.state_dict(), '%s/netD_epoch_%d.pth' % (outputDir, epoch))

# %%
cudnn.benchmark = True
os.environ['CUDA_VISIBLE_DEVICES'] = "1"
use_gpu = torch.cuda.is_available()
if use_gpu:
    print("You are using CUDA. If it is not what you want, manually set this as False!")
# Out:
# You are using CUDA. If it is not what you want, manually set this as False!

# %% [markdown]
# ### Output Directory
# This is where images will be saved to.
#
# If directory does not exist, it is created.

# %%
outputDir = 'output_WGAN_4'

try:
    os.makedirs(outputDir)
except OSError as err:
    print("OS error: {0}".format(err))

# %% [markdown]
# ### Dataset definition and hyperparameter setting
# - Changing dataset name alters network architecture parameters
# - Currently supporting few datasets
# - Hyperparameters defined according to Radford et al. (2015)

# %%
batch_size = 64

chosen_dataset = 'MNIST'

datasets = {
    'MNIST': torchvision.datasets.MNIST,
    'CIFAR10': torchvision.datasets.CIFAR10,
    'ANIME': '/home/gabriel/Redes Neurais/Projeto_Final_GANS/Tutorial_2/dataset/min_anime-faces',
}

dataset = datasets[chosen_dataset]

# %%
possible_parameters = {
    'MNIST': {
        'ndf': 64,
        'ngf': 64,
        'nz': 100,
        'nc': 1,
        'imageSize': 64,
        'n_classes' : 10,
        'ngpu': 1,
    },
    'CIFAR10': {
        'ndf': 64,
        'ngf': 64,
        'nz': 100,
        'nc': 3,
        'imageSize' : 64,
        'n_classes' : 10,
        'ngpu' : 1,
    },
    'ANIME': {
        'nc' : 3,
        'ngpu' : 1,
        'nz' : 100,
        'ngf' : 64,
        'ndf' : 64,
        'imageSize' : 64,
        'n_classes' : 1
    }
}

# %%
ngf = possible_parameters[chosen_dataset]['ngf']
ndf = possible_parameters[chosen_dataset]['ndf']
nz = possible_parameters[chosen_dataset]['nz']
nc = possible_parameters[chosen_dataset]['nc']
imageSize = possible_parameters[chosen_dataset]['imageSize']
n_classes = possible_parameters[chosen_dataset]['n_classes']
ngpu = possible_parameters[chosen_dataset]['ngpu']

# %% [markdown]
# ## Creating the Dataset!

# %%
if dataset == 'ANIME':
    dataset = torchvision.datasets.ImageFolder(
        root='/home/gabriel/Redes Neurais/Projeto_Final_GANS/Tutorial_2/dataset/min_anime-faces',
        transform=transforms.Compose([
                transforms.Scale((imageSize, imageSize)),
                transforms.ToTensor(),
            ])
    )
else:
    transform = transforms.Compose([
                    transforms.Scale((imageSize, imageSize)),
                    transforms.ToTensor(),
                    transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5)), # bring images to (-1,1)
                ]) 
    dataset_done = dataset('../Our_code/datasets', train=True, download=False, transform=transform)
    #dataloader = torch.utils.data.DataLoader(dataset_done, batch_size=batch_size, shuffle=True, num_workers=4)
#print('Dataloader length:', len(dataloader))
#print("Dataset:", dataloader.dataset)

# %% [markdown]
# ## Definição dos modelos
# - Model is a DCGAN
# - Images are sized (nc, 64, 64)

# %%
class _netD_DCGAN(nn.Module):
    def __init__(self, ngpu, nz, nc, ndf, n_classes):
        super(_netD_DCGAN, self).__init__()
        self.ngpu = ngpu
        self.conv1 = nn.Conv2d(in_channels = nc, out_channels = ndf, kernel_size=4, stride=2, padding=1, bias=False)
        self.conv2 = nn.Conv2d(in_channels = ndf, out_channels = ndf*2, kernel_size=4, stride=2, padding=1, bias=False)
        self.batch2 = nn.BatchNorm2d(ndf * 2)
        self.conv3 = nn.Conv2d(in_channels = ndf*2, out_channels = ndf*4, kernel_size=4, stride=2, padding=1, bias=False)
        self.batch3 = nn.BatchNorm2d(ndf * 4)
        self.conv4 = nn.Conv2d(in_channels = ndf*4, out_channels = ndf*8, kernel_size=4, stride=2, padding=1, bias=False)
        self.batch4 = nn.BatchNorm2d(ndf * 8)
        
        self.final_conv = nn.Conv2d(in_channels=ndf*8, out_channels=1,kernel_size=4,stride=1,padding=0,bias=False)
        
    def forward(self, x):
        x = F.leaky_relu(self.conv1(x), 0.2, inplace=True)
        x = F.leaky_relu(self.batch2(self.conv2(x)), 0.2, inplace=True)
        x = F.leaky_relu(self.batch3(self.conv3(x)), 0.2, inplace=True)
        x = F.leaky_relu(self.batch4(self.conv4(x)), 0.2, inplace=True)
        
        x = self.final_conv(x)
        x = x.mean(0)
        
        return(x.view(1))

# %%
class _netG_DCGAN(nn.Module):
    def __init__(self, ngpu, nz, nc , ngf):
        super(_netG_DCGAN, self).__init__()
        self.ngpu = ngpu
        self.convt1 = nn.ConvTranspose2d(in_channels=nz, out_channels=ngf * 8, kernel_size=4, stride=1, padding=0, bias=False)
        self.batch1 = nn.BatchNorm2d(ngf*8)
        self.convt2 = nn.ConvTranspose2d(in_channels=ngf * 8, out_channels=ngf * 4, kernel_size=4, stride=2, padding=1, bias=False)
        self.batch2 = nn.BatchNorm2d(ngf*4)
        self.convt3 = nn.ConvTranspose2d(in_channels=ngf * 4, out_channels=ngf * 2, kernel_size=4, stride=2, padding=1, bias=False)
        self.batch3 = nn.BatchNorm2d(ngf*2)
        self.convt4 = nn.ConvTranspose2d(in_channels=ngf*2, out_channels=ngf, kernel_size=4, stride=2, padding=1, bias=False)
        self.batch4 = nn.BatchNorm2d(ngf)
        
        self.final_convt = nn.ConvTranspose2d(in_channels=ngf, out_channels=nc, kernel_size=4, stride=2, padding=1, bias=False)
        
    def forward(self, x):
        x = F.leaky_relu(self.batch1(self.convt1(x)), 0.2, inplace=True)
        x = F.leaky_relu(self.batch2(self.convt2(x)), 0.2, inplace=True)
        x = F.leaky_relu(self.batch3(self.convt3(x)), 0.2, inplace=True)
        x = F.leaky_relu(self.batch4(self.convt4(x)), 0.2, inplace=True)
        
        x = self.final_convt(x)
        x = F.tanh(x)
        return (x)

# %%
netG = _netG_DCGAN(ngpu, nz, nc, ngf)
netD = _netD_DCGAN(ngpu, nz, nc, ndf, n_classes)

# %% [markdown]
# ## Inicializador de pesos

# %%
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        m.weight.data.normal_(0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        m.weight.data.normal_(1.0, 0.02)
        m.bias.data.fill_(0)

# %%
netG.apply(weights_init)
netD.apply(weights_init)
print(netG, '\n', netD)
# Out:
# _netG_DCGAN (
#   (convt1): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#   (batch1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#   (convt2): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batch2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#   (convt3): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batch3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#   (convt4): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batch4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True)
#   (final_convt): ConvTranspose2d(64, 1, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
# )
#  _netD_DCGAN (
#   (conv1): Conv2d(1, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (conv2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batch2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True)
#   (conv3): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batch3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True)
#   (conv4): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batch4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True)
#   (final_conv): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
# )

# %% [markdown]
# ## Losses
# - Binary Cross-Entropy is used to differentiate real and fake images
# - Class loss should be Cross-Entropy

# %%
criterion = nn.BCELoss()

# %% [markdown]
# ## Sizes of the tensors

# %%
input = torch.FloatTensor(batch_size, nc, imageSize, imageSize)
print('Input images size:', input.size())
noise = torch.FloatTensor(batch_size, nz, 1, 1)
fixed_noise = torch.FloatTensor(batch_size, nz, 1, 1).normal_(0, 1)
print('Code size:', noise.size())
# Out:
# Input images size: torch.Size([64, 1, 64, 64])
# Code size: torch.Size([64, 100, 1, 1])

# %%
label = torch.LongTensor(batch_size, 1)
fake_label = 0
real_label = 1

one = torch.FloatTensor([1]).cuda()
mone = -1 * one

# %% [markdown]
# ## Broadcast to GPU

# %%
if use_gpu:
    netD = netD.cuda()
    netG = netG.cuda()
    criterion = criterion.cuda()
    input,label = input.cuda(), label.cuda()
    noise, fixed_noise = noise.cuda(), fixed_noise.cuda()

# %% [markdown]
# ## Optimizer Parameters
# - Following the lead of [WGAN](https://arxiv.org/pdf/1701.07875.pdf):
#
#     <b>
#     1. Optimizer is RMSprop
#     2. lr = 0.00005
#     </b>

# %%
lr = 1e-4

optimizerD = optim.RMSprop(netD.parameters(), lr = lr)
optimizerG = optim.RMSprop(netG.parameters(), lr = lr)

# %% [markdown]
# ## Treinamento

# %%
def train_gan(num_epochs, dataloader, netD, netG, outputDir,
              real_labelSmooth=0, epoch_interval=100, D_steps=5, G_steps=1, atenuation_epochs=25):
    
    # This validation is subjective. WGAN-GP uses 100 steps on the critic (netD).
    #assert D_steps < 5, "Keep it low, D_steps is too high."
    #assert G_steps < 3, "Keep it low, G_steps is too high."
    #assert batch_size % D_steps == 0, "Use batch_size multiple of D_steps."
    print('Lets train!')
    for epoch in range(num_epochs):
        start_iter = time.time()

        for batch, data in enumerate(dataloader, 0):
            if (epoch == 0 and batch == 0):
                    vutils.save_image(data[0][0:64,:,:,:], '%s/real_samples.png' % outputDir, nrow=8)
            
            for p in netD.parameters():
                p.requires_grad = True
            
            for step in range(D_steps):
                for p in netD.parameters():
                    p.data.clamp_(-0.01, 0.01)
                    
                #############################################################
                # (1) Update D network: maximize log(D(x)) + log(1 - D(G(z)))
                # 1A - Train the detective network in the Real Dataset
                #############################################################
                netD.zero_grad()
                start = step*(int(data[0].size()[0]/D_steps))
                end = (step+1)*int(data[0].size()[0]/D_steps)
                
                real_cpu = data[0][start:end]
                real_cpu = real_cpu.cuda()
                batch_size = real_cpu.size(0)
                target = torch.LongTensor(batch_size).fill_(real_label).cuda()
                
                input, label = Variable(real_cpu), Variable(target)

                errD_real = netD(input)
                errD_real.backward(one)
                
                #######################################################
                # 1B - Train the detective network in the False Dataset
                #######################################################
                
                noise = Variable(torch.FloatTensor(batch_size, nz, 1, 1).normal_(0,1).cuda())
                fake = netG(noise)
                label = Variable(torch.ones(batch_size).long().fill_(fake_label).cuda())

                errD_fake = netD(fake.detach())
                errD_fake.backward(mone)
                errD = errD_real - errD_fake
                optimizerD.step()

            for p in netD.parameters():
                p.requires_grad = False
                
            for step in range(G_steps):
                ####################################################################################
                # (2) Update G network: maximize log(D(G(z)))
                # Train the faker with the output from the Detective (but don't train the Detective)
                ####################################################################################
                
                netG.zero_grad()
                label = Variable(torch.LongTensor(batch_size).fill_(real_label).cuda())
                errG = netD(fake)
                
                errG.backward(one)
                optimizerG.step()
                
        print('epoch = ',epoch)

        end_iter = time.time()        

        print('[%d/%d] ErrD: %.2f, ErrG: %.2f, ErrD_real: %.2f, ErrD_fake: %.2f, Time Elapsed %.2f s'
              % (epoch, num_epochs, errD.data[0], errG.data[0], errD_real.data[0], errD_fake.data[0], end_iter-start_iter))

        #Save a grid with the pictures from the dataset, up until 64
        save_images(netG = netG, fixed_noise=  fixed_noise, outputDir = outputDir, epoch = epoch)

        if epoch % epoch_interval == 0:
            # do checkpointing
            save_models(netG = netG, netD = netD, outputDir = outputDir, epoch = epoch)

# %%
num_epochs = 250
real_labelSmooth = 0
smoothing_epochs = 25
D_steps = 5
dataloader = torch.utils.data.DataLoader(dataset_done, batch_size=batch_size*D_steps, shuffle=True, num_workers=4)
train_gan(num_epochs, dataloader, netD,netG, outputDir, real_labelSmooth, D_steps = D_steps, atenuation_epochs=smoothing_epochs)
# Out:
# Lets train!
# epoch =  0
# [0/250] ErrD: -1.04, ErrG: 0.63, ErrD_real: -0.62, ErrD_fake: 0.42, Time Elapsed 32.07 s
# epoch =  1
# [1/250] ErrD: -1.16, ErrG: 0.67, ErrD_real: -0.65, ErrD_fake: 0.51, Time Elapsed 31.75 s
# epoch =  2
# [2/250] ErrD: -1.02, ErrG: 0.65, ErrD_real: -0.59, ErrD_fake: 0.43, Time Elapsed 31.87 s
# epoch =  3
# [3/250] ErrD: -0.87, ErrG: 0.62, ErrD_real: -0.61, ErrD_fake: 0.26, Time Elapsed 31.74 s
# epoch =  4
# [4/250] ErrD: -1.11, ErrG: 0.64, ErrD_real: -0.62, ErrD_fake: 0.50, Time Elapsed 31.85 s
# epoch =  5
# [5/250] ErrD: -1.02, ErrG: 0.51, ErrD_real: -0.45, ErrD_fake: 0.57, Time Elapsed 31.94 s
# epoch =  6
# [6/250] ErrD: -1.14, ErrG: 0.65, ErrD_real: -0.66, ErrD_fake: 0.48, Time Elapsed 32.12 s
# epoch =  7
# [7/250] ErrD: -1.05, ErrG: 0.32, ErrD_real: -0.43, ErrD_fake: 0.61, Time Elapsed 32.15 s
# epoch =  8
# [8/250] ErrD: -0.78, ErrG: 0.05, ErrD_real: -0.21, ErrD_fake: 0.58, Time Elapsed 32.26 s
# epoch =  9
# [9/250] ErrD: -1.26, ErrG: 0.68, ErrD_real: -0.67, ErrD_fake: 0.59, Time Elapsed 32.33 s
# epoch =  10
# [10/250] ErrD: -1.05, ErrG: 0.68, ErrD_real: -0.65, ErrD_fake: 0.40, Time Elapsed 32.35 s
# epoch =  11
# [11/250] ErrD: -1.18, ErrG: 0.66, ErrD_real: -0.64, ErrD_fake: 0.54, Time Elapsed 32.28 s
# epoch =  12
# [12/250] ErrD: -1.32, ErrG: 0.69, ErrD_real: -0.66, ErrD_fake: 0.66, Time Elapsed 32.29 s
# epoch =  13
# [13/250] ErrD: -1.11, ErrG: 0.49, ErrD_real: -0.47, ErrD_fake: 0.64, Time Elapsed 32.34 s
# epoch =  14
# [14/250] ErrD: -0.85, ErrG: 0.30, ErrD_real: -0.28, ErrD_fake: 0.57, Time Elapsed 32.29 s
# epoch =  15
# [15/250] ErrD: -0.96, ErrG: 0.67, ErrD_real: -0.65, ErrD_fake: 0.31, Time Elapsed 32.31 s
# epoch =  16
# [16/250] ErrD: -1.19, ErrG: 0.64, ErrD_real: -0.63, ErrD_fake: 0.56, Time Elapsed 32.42 s
# epoch =  17
# [17/250] ErrD: -0.75, ErrG: 0.11, ErrD_real: -0.14, ErrD_fake: 0.61, Time Elapsed 32.52 s
# epoch =  18
# [18/250] ErrD: -0.90, ErrG: 0.67, ErrD_real: -0.63, ErrD_fake: 0.27, Time Elapsed 32.39 s
# epoch =  19
# [19/250] ErrD: -0.95, ErrG: 0.35, ErrD_real: -0.33, ErrD_fake: 0.62, Time Elapsed 32.40 s
# epoch =  20
# [20/250] ErrD: -1.06, ErrG: 0.68, ErrD_real: -0.64, ErrD_fake: 0.42, Time Elapsed 32.49 s
# epoch =  21
# [21/250] ErrD: -0.99, ErrG: 0.66, ErrD_real: -0.63, ErrD_fake: 0.36, Time Elapsed 32.39 s
# epoch =  22
# [22/250] ErrD: -1.25, ErrG: 0.64, ErrD_real: -0.61, ErrD_fake: 0.64, Time Elapsed 32.48 s
# epoch =  23
# [23/250] ErrD: -1.32, ErrG: 0.69, ErrD_real: -0.66, ErrD_fake: 0.66, Time Elapsed 32.37 s
# epoch =  24
# [24/250] ErrD: -0.91, ErrG: 0.22, ErrD_real: -0.30, ErrD_fake: 0.60, Time Elapsed 32.37 s
# epoch =  25
# [25/250] ErrD: -1.07, ErrG: 0.67, ErrD_real: -0.64, ErrD_fake: 0.43, Time Elapsed 32.43 s
# epoch =  26
# [26/250] ErrD: -1.26, ErrG: 0.66, ErrD_real: -0.65, ErrD_fake: 0.61, Time Elapsed 32.29 s
# epoch =  27
# [27/250] ErrD: -1.20, ErrG: 0.67, ErrD_real: -0.66, ErrD_fake: 0.54, Time Elapsed 32.43 s
# epoch =  28
# [28/250] ErrD: -1.08, ErrG: 0.66, ErrD_real: -0.66, ErrD_fake: 0.42, Time Elapsed 32.31 s
# epoch =  29
# [29/250] ErrD: -1.01, ErrG: 0.64, ErrD_real: -0.61, ErrD_fake: 0.40, Time Elapsed 32.42 s
# epoch =  30
# [30/250] ErrD: -1.14, ErrG: 0.57, ErrD_real: -0.55, ErrD_fake: 0.59, Time Elapsed 32.37 s
# epoch =  31
# [31/250] ErrD: -0.98, ErrG: 0.40, ErrD_real: -0.38, ErrD_fake: 0.60, Time Elapsed 32.47 s
# epoch =  32
# [32/250] ErrD: -0.89, ErrG: 0.20, ErrD_real: -0.28, ErrD_fake: 0.61, Time Elapsed 32.36 s
# epoch =  33
# [33/250] ErrD: -1.07, ErrG: 0.66, ErrD_real: -0.65, ErrD_fake: 0.43, Time Elapsed 32.53 s
# epoch =  34
# [34/250] ErrD: -0.93, ErrG: 0.10, ErrD_real: -0.32, ErrD_fake: 0.61, Time Elapsed 32.33 s
# epoch =  35
# [35/250] ErrD: -0.82, ErrG: 0.65, ErrD_real: -0.60, ErrD_fake: 0.22, Time Elapsed 32.59 s
# epoch =  36
# [36/250] ErrD: -0.97, ErrG: 0.23, ErrD_real: -0.39, ErrD_fake: 0.58, Time Elapsed 32.42 s
# epoch =  37
# [37/250] ErrD: -0.90, ErrG: 0.27, ErrD_real: -0.29, ErrD_fake: 0.60, Time Elapsed 32.59 s
# epoch =  38
# [38/250] ErrD: -1.02, ErrG: 0.66, ErrD_real: -0.63, ErrD_fake: 0.39, Time Elapsed 32.55 s
# epoch =  39
# [39/250] ErrD: -1.08, ErrG: 0.66, ErrD_real: -0.64, ErrD_fake: 0.44, Time Elapsed 32.44 s
# epoch =  40
# [40/250] ErrD: -1.17, ErrG: 0.63, ErrD_real: -0.59, ErrD_fake: 0.57, Time Elapsed 32.54 s
# epoch =  41
# [41/250] ErrD: -0.71, ErrG: 0.64, ErrD_real: -0.63, ErrD_fake: 0.08, Time Elapsed 32.40 s
# epoch =  42
# [42/250] ErrD: -0.88, ErrG: 0.27, ErrD_real: -0.31, ErrD_fake: 0.57, Time Elapsed 32.50 s
# epoch =  43
# [43/250] ErrD: -0.92, ErrG: 0.29, ErrD_real: -0.36, ErrD_fake: 0.55, Time Elapsed 32.49 s
# epoch =  44
# [44/250] ErrD: -0.66, ErrG: 0.61, ErrD_real: -0.61, ErrD_fake: 0.05, Time Elapsed 32.65 s
# epoch =  45
# [45/250] ErrD: -0.89, ErrG: 0.66, ErrD_real: -0.62, ErrD_fake: 0.27, Time Elapsed 32.38 s
# epoch =  46
# [46/250] ErrD: -0.86, ErrG: 0.59, ErrD_real: -0.51, ErrD_fake: 0.35, Time Elapsed 32.46 s
# epoch =  47
# [47/250] ErrD: -1.01, ErrG: 0.26, ErrD_real: -0.40, ErrD_fake: 0.61, Time Elapsed 32.46 s
# epoch =  48
# [48/250] ErrD: -1.05, ErrG: 0.57, ErrD_real: -0.54, ErrD_fake: 0.51, Time Elapsed 32.52 s
# epoch =  49
# [49/250] ErrD: -1.10, ErrG: 0.59, ErrD_real: -0.57, ErrD_fake: 0.54, Time Elapsed 32.50 s
# epoch =  50
# [50/250] ErrD: -1.08, ErrG: 0.50, ErrD_real: -0.50, ErrD_fake: 0.58, Time Elapsed 32.46 s
# epoch =  51
# [51/250] ErrD: -0.94, ErrG: 0.64, ErrD_real: -0.60, ErrD_fake: 0.34, Time Elapsed 32.54 s
# epoch =  52
# [52/250] ErrD: -1.05, ErrG: 0.43, ErrD_real: -0.46, ErrD_fake: 0.59, Time Elapsed 32.63 s
# epoch =  53
# [53/250] ErrD: -0.85, ErrG: 0.63, ErrD_real: -0.58, ErrD_fake: 0.27, Time Elapsed 32.54 s
# epoch =  54
# [54/250] ErrD: -0.94, ErrG: 0.40, ErrD_real: -0.38, ErrD_fake: 0.56, Time Elapsed 32.55 s
# epoch =  55
# [55/250] ErrD: -1.19, ErrG: 0.63, ErrD_real: -0.60, ErrD_fake: 0.59, Time Elapsed 32.68 s
# epoch =  56
# [56/250] ErrD: -0.97, ErrG: 0.43, ErrD_real: -0.40, ErrD_fake: 0.57, Time Elapsed 32.47 s
# epoch =  57
# [57/250] ErrD: -0.97, ErrG: 0.43, ErrD_real: -0.45, ErrD_fake: 0.52, Time Elapsed 32.59 s
# epoch =  58
# [58/250] ErrD: -0.95, ErrG: 0.23, ErrD_real: -0.36, ErrD_fake: 0.59, Time Elapsed 32.46 s
# epoch =  59
# [59/250] ErrD: -0.72, ErrG: 0.64, ErrD_real: -0.56, ErrD_fake: 0.17, Time Elapsed 32.63 s
# epoch =  60
# [60/250] ErrD: -0.63, ErrG: 0.14, ErrD_real: -0.09, ErrD_fake: 0.54, Time Elapsed 32.52 s
# epoch =  61
# [61/250] ErrD: -0.65, ErrG: 0.04, ErrD_real: -0.08, ErrD_fake: 0.57, Time Elapsed 32.52 s
# epoch =  62
# [62/250] ErrD: -0.67, ErrG: 0.63, ErrD_real: -0.55, ErrD_fake: 0.12, Time Elapsed 32.45 s
# epoch =  63
# [63/250] ErrD: -0.85, ErrG: 0.63, ErrD_real: -0.58, ErrD_fake: 0.28, Time Elapsed 32.67 s
# epoch =  64
# [64/250] ErrD: -0.92, ErrG: 0.41, ErrD_real: -0.38, ErrD_fake: 0.54, Time Elapsed 32.46 s
# epoch =  65
# [65/250] ErrD: -0.64, ErrG: 0.11, ErrD_real: -0.08, ErrD_fake: 0.56, Time Elapsed 32.61 s
# epoch =  66
# [66/250] ErrD: -0.80, ErrG: 0.62, ErrD_real: -0.54, ErrD_fake: 0.26, Time Elapsed 32.53 s
# epoch =  67
# [67/250] ErrD: -0.89, ErrG: 0.22, ErrD_real: -0.31, ErrD_fake: 0.58, Time Elapsed 32.55 s
# epoch =  68
# [68/250] ErrD: -0.74, ErrG: 0.13, ErrD_real: -0.22, ErrD_fake: 0.51, Time Elapsed 32.75 s
# epoch =  69
# [69/250] ErrD: -0.71, ErrG: 0.60, ErrD_real: -0.55, ErrD_fake: 0.16, Time Elapsed 32.44 s
# epoch =  70
# [70/250] ErrD: -0.82, ErrG: 0.29, ErrD_real: -0.30, ErrD_fake: 0.52, Time Elapsed 32.61 s
# epoch =  71
# [71/250] ErrD: -1.06, ErrG: 0.65, ErrD_real: -0.61, ErrD_fake: 0.44, Time Elapsed 32.51 s
# epoch =  72
# [72/250] ErrD: -0.60, ErrG: 0.12, ErrD_real: -0.05, ErrD_fake: 0.55, Time Elapsed 32.72 s
# epoch =  73
# [73/250] ErrD: -0.88, ErrG: 0.41, ErrD_real: -0.39, ErrD_fake: 0.50, Time Elapsed 32.64 s
# epoch =  74
# [74/250] ErrD: -0.85, ErrG: 0.61, ErrD_real: -0.57, ErrD_fake: 0.28, Time Elapsed 32.62 s
# epoch =  75
# [75/250] ErrD: -0.92, ErrG: 0.39, ErrD_real: -0.37, ErrD_fake: 0.55, Time Elapsed 32.60 s
# epoch =  76
# [76/250] ErrD: -0.86, ErrG: 0.21, ErrD_real: -0.30, ErrD_fake: 0.56, Time Elapsed 32.63 s
# epoch =  77
# [77/250] ErrD: -0.80, ErrG: 0.61, ErrD_real: -0.56, ErrD_fake: 0.24, Time Elapsed 32.62 s
# epoch =  78
# [78/250] ErrD: -0.82, ErrG: 0.60, ErrD_real: -0.54, ErrD_fake: 0.28, Time Elapsed 32.50 s
# epoch =  79
# [79/250] ErrD: -0.74, ErrG: 0.61, ErrD_real: -0.53, ErrD_fake: 0.22, Time Elapsed 32.52 s
# epoch =  80
# [80/250] ErrD: -0.74, ErrG: 0.16, ErrD_real: -0.17, ErrD_fake: 0.57, Time Elapsed 32.73 s
# epoch =  81
# [81/250] ErrD: -0.58, ErrG: 0.19, ErrD_real: -0.06, ErrD_fake: 0.52, Time Elapsed 32.61 s
# epoch =  82
# [82/250] ErrD: -0.83, ErrG: 0.29, ErrD_real: -0.29, ErrD_fake: 0.53, Time Elapsed 32.61 s
# epoch =  83
# [83/250] ErrD: -0.72, ErrG: 0.29, ErrD_real: -0.17, ErrD_fake: 0.55, Time Elapsed 32.58 s
# epoch =  84
# [84/250] ErrD: -0.88, ErrG: 0.30, ErrD_real: -0.33, ErrD_fake: 0.55, Time Elapsed 32.66 s
# epoch =  85
# [85/250] ErrD: -0.59, ErrG: 0.59, ErrD_real: -0.60, ErrD_fake: -0.01, Time Elapsed 32.80 s
# epoch =  86
# [86/250] ErrD: -0.76, ErrG: 0.61, ErrD_real: -0.52, ErrD_fake: 0.25, Time Elapsed 32.65 s
# epoch =  87
# [87/250] ErrD: -0.80, ErrG: 0.29, ErrD_real: -0.32, ErrD_fake: 0.48, Time Elapsed 32.65 s
# epoch =  88
# [88/250] ErrD: -0.80, ErrG: 0.36, ErrD_real: -0.34, ErrD_fake: 0.46, Time Elapsed 32.61 s
# epoch =  89
# [89/250] ErrD: -0.69, ErrG: 0.28, ErrD_real: -0.20, ErrD_fake: 0.49, Time Elapsed 32.67 s
# epoch =  90
# [90/250] ErrD: -0.74, ErrG: 0.61, ErrD_real: -0.57, ErrD_fake: 0.18, Time Elapsed 32.70 s
# epoch =  91
# [91/250] ErrD: -0.99, ErrG: 0.63, ErrD_real: -0.58, ErrD_fake: 0.42, Time Elapsed 32.80 s
# epoch =  92
# [92/250] ErrD: -0.63, ErrG: 0.61, ErrD_real: -0.57, ErrD_fake: 0.06, Time Elapsed 32.59 s
# epoch =  93
# [93/250] ErrD: -0.74, ErrG: 0.63, ErrD_real: -0.60, ErrD_fake: 0.14, Time Elapsed 32.68 s
# epoch =  94
# [94/250] ErrD: -0.83, ErrG: 0.22, ErrD_real: -0.26, ErrD_fake: 0.56, Time Elapsed 32.57 s
# epoch =  95
# [95/250] ErrD: -0.68, ErrG: 0.27, ErrD_real: -0.21, ErrD_fake: 0.47, Time Elapsed 32.72 s
# epoch =  96
# [96/250] ErrD: -0.67, ErrG: 0.21, ErrD_real: -0.20, ErrD_fake: 0.47, Time Elapsed 32.78 s
# epoch =  97
# [97/250] ErrD: -0.90, ErrG: 0.59, ErrD_real: -0.53, ErrD_fake: 0.37, Time Elapsed 32.52 s
# epoch =  98
# [98/250] ErrD: -0.74, ErrG: 0.53, ErrD_real: -0.45, ErrD_fake: 0.29, Time Elapsed 32.67 s
# epoch =  99
# [99/250] ErrD: -1.00, ErrG: 0.58, ErrD_real: -0.55, ErrD_fake: 0.45, Time Elapsed 32.60 s
# epoch =  100
# [100/250] ErrD: -0.69, ErrG: 0.20, ErrD_real: -0.21, ErrD_fake: 0.48, Time Elapsed 32.59 s
# epoch =  101
# [101/250] ErrD: -0.67, ErrG: 0.21, ErrD_real: -0.20, ErrD_fake: 0.48, Time Elapsed 32.67 s
# epoch =  102
# [102/250] ErrD: -0.88, ErrG: 0.56, ErrD_real: -0.51, ErrD_fake: 0.38, Time Elapsed 32.71 s
# epoch =  103
# [103/250] ErrD: -0.64, ErrG: 0.59, ErrD_real: -0.56, ErrD_fake: 0.08, Time Elapsed 32.67 s
# epoch =  104
# [104/250] ErrD: -0.83, ErrG: 0.16, ErrD_real: -0.25, ErrD_fake: 0.58, Time Elapsed 32.78 s
# epoch =  105
# [105/250] ErrD: -0.72, ErrG: 0.56, ErrD_real: -0.50, ErrD_fake: 0.22, Time Elapsed 32.65 s
# epoch =  106
# [106/250] ErrD: -0.93, ErrG: 0.48, ErrD_real: -0.46, ErrD_fake: 0.47, Time Elapsed 32.73 s
# epoch =  107
# [107/250] ErrD: -0.88, ErrG: 0.28, ErrD_real: -0.32, ErrD_fake: 0.56, Time Elapsed 32.76 s
# epoch =  108
# [108/250] ErrD: -0.81, ErrG: 0.59, ErrD_real: -0.54, ErrD_fake: 0.27, Time Elapsed 32.64 s
# epoch =  109
# [109/250] ErrD: -0.67, ErrG: 0.21, ErrD_real: -0.20, ErrD_fake: 0.47, Time Elapsed 32.83 s
# epoch =  110
# [110/250] ErrD: -0.82, ErrG: 0.59, ErrD_real: -0.53, ErrD_fake: 0.29, Time Elapsed 32.59 s
# epoch =  111
# [111/250] ErrD: -0.87, ErrG: 0.58, ErrD_real: -0.53, ErrD_fake: 0.34, Time Elapsed 32.71 s
# epoch =  112
# [112/250] ErrD: -0.51, ErrG: 0.49, ErrD_real: -0.54, ErrD_fake: -0.03, Time Elapsed 32.68 s
# epoch =  113
# [113/250] ErrD: -0.69, ErrG: 0.59, ErrD_real: -0.53, ErrD_fake: 0.16, Time Elapsed 32.67 s
# epoch =  114
# [114/250] ErrD: -0.74, ErrG: 0.39, ErrD_real: -0.34, ErrD_fake: 0.40, Time Elapsed 32.58 s
# epoch =  115
# [115/250] ErrD: -0.53, ErrG: 0.25, ErrD_real: -0.11, ErrD_fake: 0.42, Time Elapsed 32.64 s
# epoch =  116
# [116/250] ErrD: -0.73, ErrG: 0.22, ErrD_real: -0.21, ErrD_fake: 0.52, Time Elapsed 32.58 s
# epoch =  117
# [117/250] ErrD: -0.78, ErrG: 0.26, ErrD_real: -0.29, ErrD_fake: 0.49, Time Elapsed 32.75 s
# epoch =  118
# [118/250] ErrD: -0.82, ErrG: 0.32, ErrD_real: -0.32, ErrD_fake: 0.50, Time Elapsed 32.70 s
# epoch =  119
# [119/250] ErrD: -0.86, ErrG: 0.32, ErrD_real: -0.32, ErrD_fake: 0.55, Time Elapsed 32.70 s
# epoch =  120
# [120/250] ErrD: -0.67, ErrG: 0.59, ErrD_real: -0.55, ErrD_fake: 0.12, Time Elapsed 32.65 s
# epoch =  121
# [121/250] ErrD: -0.75, ErrG: 0.57, ErrD_real: -0.49, ErrD_fake: 0.27, Time Elapsed 32.65 s
# epoch =  122
# [122/250] ErrD: -0.68, ErrG: 0.25, ErrD_real: -0.16, ErrD_fake: 0.52, Time Elapsed 32.77 s
# epoch =  123
# [123/250] ErrD: -0.90, ErrG: 0.31, ErrD_real: -0.34, ErrD_fake: 0.56, Time Elapsed 32.63 s
# epoch =  124
# [124/250] ErrD: -0.67, ErrG: 0.54, ErrD_real: -0.50, ErrD_fake: 0.17, Time Elapsed 32.75 s
# epoch =  125
# [125/250] ErrD: -0.75, ErrG: 0.19, ErrD_real: -0.23, ErrD_fake: 0.52, Time Elapsed 32.71 s
# epoch =  126
# [126/250] ErrD: -0.66, ErrG: 0.58, ErrD_real: -0.60, ErrD_fake: 0.06, Time Elapsed 32.69 s
# epoch =  127
# [127/250] ErrD: -0.67, ErrG: 0.55, ErrD_real: -0.50, ErrD_fake: 0.17, Time Elapsed 32.85 s
# epoch =  128
# [128/250] ErrD: -0.90, ErrG: 0.62, ErrD_real: -0.56, ErrD_fake: 0.34, Time Elapsed 32.62 s
# epoch =  129
# [129/250] ErrD: -0.74, ErrG: 0.59, ErrD_real: -0.55, ErrD_fake: 0.20, Time Elapsed 32.68 s
# epoch =  130
# [130/250] ErrD: -0.72, ErrG: 0.55, ErrD_real: -0.49, ErrD_fake: 0.23, Time Elapsed 32.64 s
# epoch =  131
# [131/250] ErrD: -0.73, ErrG: 0.58, ErrD_real: -0.45, ErrD_fake: 0.28, Time Elapsed 32.78 s
# epoch =  132
# [132/250] ErrD: -0.67, ErrG: 0.59, ErrD_real: -0.50, ErrD_fake: 0.17, Time Elapsed 32.60 s
# epoch =  133
# [133/250] ErrD: -0.72, ErrG: 0.57, ErrD_real: -0.53, ErrD_fake: 0.19, Time Elapsed 32.74 s
# epoch =  134
# [134/250] ErrD: -0.75, ErrG: 0.59, ErrD_real: -0.53, ErrD_fake: 0.22, Time Elapsed 32.53 s
# epoch =  135
# [135/250] ErrD: -0.78, ErrG: 0.54, ErrD_real: -0.51, ErrD_fake: 0.27, Time Elapsed 32.62 s
# epoch =  136
# [136/250] ErrD: -0.73, ErrG: 0.07, ErrD_real: -0.17, ErrD_fake: 0.56, Time Elapsed 32.75 s
# epoch =  137
# [137/250] ErrD: -0.68, ErrG: 0.09, ErrD_real: -0.17, ErrD_fake: 0.51, Time Elapsed 32.62 s
# epoch =  138
# [138/250] ErrD: -0.63, ErrG: 0.56, ErrD_real: -0.51, ErrD_fake: 0.11, Time Elapsed 32.85 s
# epoch =  139
# [139/250] ErrD: -0.80, ErrG: 0.59, ErrD_real: -0.53, ErrD_fake: 0.28, Time Elapsed 32.63 s
# epoch =  140
# [140/250] ErrD: -0.81, ErrG: 0.58, ErrD_real: -0.55, ErrD_fake: 0.26, Time Elapsed 32.78 s
# epoch =  141
# [141/250] ErrD: -0.70, ErrG: 0.60, ErrD_real: -0.52, ErrD_fake: 0.19, Time Elapsed 32.63 s
# epoch =  142
# [142/250] ErrD: -0.92, ErrG: 0.58, ErrD_real: -0.54, ErrD_fake: 0.38, Time Elapsed 32.86 s
# epoch =  143
# [143/250] ErrD: -0.75, ErrG: 0.55, ErrD_real: -0.48, ErrD_fake: 0.27, Time Elapsed 32.86 s
# epoch =  144
# [144/250] ErrD: -0.70, ErrG: 0.56, ErrD_real: -0.49, ErrD_fake: 0.20, Time Elapsed 32.85 s
# epoch =  145
# [145/250] ErrD: -0.59, ErrG: 0.10, ErrD_real: -0.11, ErrD_fake: 0.48, Time Elapsed 32.82 s
# epoch =  146
# [146/250] ErrD: -0.70, ErrG: 0.27, ErrD_real: -0.27, ErrD_fake: 0.43, Time Elapsed 32.87 s
# epoch =  147
# [147/250] ErrD: -0.75, ErrG: 0.17, ErrD_real: -0.24, ErrD_fake: 0.51, Time Elapsed 32.77 s
# epoch =  148
# [148/250] ErrD: -0.52, ErrG: 0.10, ErrD_real: -0.01, ErrD_fake: 0.51, Time Elapsed 32.83 s
# epoch =  149
# [149/250] ErrD: -0.84, ErrG: 0.27, ErrD_real: -0.29, ErrD_fake: 0.54, Time Elapsed 32.80 s
# epoch =  150
# [150/250] ErrD: -0.72, ErrG: 0.41, ErrD_real: -0.34, ErrD_fake: 0.38, Time Elapsed 32.82 s
# epoch =  151
# [151/250] ErrD: -0.79, ErrG: 0.39, ErrD_real: -0.38, ErrD_fake: 0.41, Time Elapsed 32.75 s
# epoch =  152
# [152/250] ErrD: -0.62, ErrG: 0.21, ErrD_real: -0.13, ErrD_fake: 0.50, Time Elapsed 32.86 s
# epoch =  153
# [153/250] ErrD: -0.56, ErrG: 0.23, ErrD_real: -0.15, ErrD_fake: 0.42, Time Elapsed 32.77 s
# epoch =  154
# [154/250] ErrD: -0.56, ErrG: 0.55, ErrD_real: -0.53, ErrD_fake: 0.03, Time Elapsed 32.85 s
# epoch =  155
# [155/250] ErrD: -0.63, ErrG: 0.23, ErrD_real: -0.14, ErrD_fake: 0.49, Time Elapsed 32.77 s
# epoch =  156
# [156/250] ErrD: -0.67, ErrG: 0.59, ErrD_real: -0.49, ErrD_fake: 0.18, Time Elapsed 32.85 s
# epoch =  157
# [157/250] ErrD: -0.72, ErrG: 0.59, ErrD_real: -0.52, ErrD_fake: 0.20, Time Elapsed 32.82 s
# epoch =  158
# [158/250] ErrD: -0.51, ErrG: 0.08, ErrD_real: -0.08, ErrD_fake: 0.44, Time Elapsed 32.75 s
# epoch =  159
# [159/250] ErrD: -0.76, ErrG: 0.20, ErrD_real: -0.26, ErrD_fake: 0.50, Time Elapsed 32.85 s
# epoch =  160
# [160/250] ErrD: -0.71, ErrG: 0.60, ErrD_real: -0.51, ErrD_fake: 0.20, Time Elapsed 32.80 s
# epoch =  161
# [161/250] ErrD: -0.59, ErrG: 0.58, ErrD_real: -0.53, ErrD_fake: 0.06, Time Elapsed 32.85 s
# epoch =  162
# [162/250] ErrD: -0.56, ErrG: 0.52, ErrD_real: -0.45, ErrD_fake: 0.11, Time Elapsed 32.76 s
# epoch =  163
# [163/250] ErrD: -0.63, ErrG: 0.58, ErrD_real: -0.53, ErrD_fake: 0.10, Time Elapsed 32.83 s
# epoch =  164
# [164/250] ErrD: -0.76, ErrG: 0.59, ErrD_real: -0.55, ErrD_fake: 0.21, Time Elapsed 32.84 s
# epoch =  165
# [165/250] ErrD: -0.59, ErrG: 0.54, ErrD_real: -0.53, ErrD_fake: 0.06, Time Elapsed 32.82 s
# epoch =  166
# [166/250] ErrD: -0.68, ErrG: 0.33, ErrD_real: -0.22, ErrD_fake: 0.46, Time Elapsed 32.83 s
# epoch =  167
# [167/250] ErrD: -0.58, ErrG: 0.35, ErrD_real: -0.28, ErrD_fake: 0.30, Time Elapsed 32.73 s
# epoch =  168
# [168/250] ErrD: -0.76, ErrG: 0.40, ErrD_real: -0.37, ErrD_fake: 0.39, Time Elapsed 32.85 s
# epoch =  169
# [169/250] ErrD: -0.63, ErrG: 0.09, ErrD_real: -0.12, ErrD_fake: 0.51, Time Elapsed 32.76 s
# epoch =  170
# [170/250] ErrD: -0.74, ErrG: 0.34, ErrD_real: -0.31, ErrD_fake: 0.43, Time Elapsed 32.83 s
# epoch =  171
# [171/250] ErrD: -0.71, ErrG: 0.17, ErrD_real: -0.19, ErrD_fake: 0.52, Time Elapsed 32.78 s
# epoch =  172
# [172/250] ErrD: -0.64, ErrG: 0.23, ErrD_real: -0.23, ErrD_fake: 0.41, Time Elapsed 32.77 s
# epoch =  173
# [173/250] ErrD: -0.64, ErrG: 0.29, ErrD_real: -0.26, ErrD_fake: 0.38, Time Elapsed 32.74 s
# epoch =  174
# [174/250] ErrD: -0.70, ErrG: 0.54, ErrD_real: -0.53, ErrD_fake: 0.18, Time Elapsed 32.88 s
# epoch =  175
# [175/250] ErrD: -0.71, ErrG: 0.57, ErrD_real: -0.49, ErrD_fake: 0.22, Time Elapsed 32.80 s
# epoch =  176
# [176/250] ErrD: -0.51, ErrG: 0.08, ErrD_real: 0.00, ErrD_fake: 0.51, Time Elapsed 32.75 s
# epoch =  177
# [177/250] ErrD: -0.71, ErrG: 0.24, ErrD_real: -0.24, ErrD_fake: 0.46, Time Elapsed 32.87 s
# epoch =  178
# [178/250] ErrD: -0.63, ErrG: 0.25, ErrD_real: -0.20, ErrD_fake: 0.43, Time Elapsed 32.75 s
# epoch =  179
# [179/250] ErrD: -0.63, ErrG: 0.20, ErrD_real: -0.18, ErrD_fake: 0.44, Time Elapsed 32.86 s
# epoch =  180
# [180/250] ErrD: -0.59, ErrG: 0.08, ErrD_real: -0.19, ErrD_fake: 0.40, Time Elapsed 32.75 s
# epoch =  181
# [181/250] ErrD: -0.71, ErrG: 0.59, ErrD_real: -0.53, ErrD_fake: 0.18, Time Elapsed 32.86 s
# epoch =  182
# [182/250] ErrD: -0.65, ErrG: 0.58, ErrD_real: -0.53, ErrD_fake: 0.12, Time Elapsed 32.76 s
# epoch =  183
# [183/250] ErrD: -0.63, ErrG: 0.26, ErrD_real: -0.23, ErrD_fake: 0.41, Time Elapsed 32.85 s
# epoch =  184
# [184/250] ErrD: -0.85, ErrG: 0.34, ErrD_real: -0.32, ErrD_fake: 0.52, Time Elapsed 32.79 s
# epoch =  185
# [185/250] ErrD: -0.68, ErrG: 0.13, ErrD_real: -0.13, ErrD_fake: 0.55, Time Elapsed 32.78 s
# epoch =  186
# [186/250] ErrD: -0.70, ErrG: 0.35, ErrD_real: -0.30, ErrD_fake: 0.40, Time Elapsed 32.86 s
# epoch =  187
# [187/250] ErrD: -0.60, ErrG: 0.35, ErrD_real: -0.24, ErrD_fake: 0.36, Time Elapsed 32.89 s
# epoch =  188
# [188/250] ErrD: -0.59, ErrG: 0.28, ErrD_real: -0.26, ErrD_fake: 0.33, Time Elapsed 32.83 s
# epoch =  189
# [189/250] ErrD: -0.77, ErrG: 0.58, ErrD_real: -0.53, ErrD_fake: 0.24, Time Elapsed 32.81 s
# epoch =  190
# [190/250] ErrD: -0.56, ErrG: 0.07, ErrD_real: -0.03, ErrD_fake: 0.53, Time Elapsed 32.85 s
# epoch =  191
# [191/250] ErrD: -0.64, ErrG: 0.07, ErrD_real: -0.11, ErrD_fake: 0.53, Time Elapsed 32.77 s
# epoch =  192
# [192/250] ErrD: -0.47, ErrG: 0.14, ErrD_real: -0.00, ErrD_fake: 0.47, Time Elapsed 32.81 s
# epoch =  193
# [193/250] ErrD: -0.71, ErrG: 0.52, ErrD_real: -0.47, ErrD_fake: 0.24, Time Elapsed 32.80 s
# epoch =  194
# [194/250] ErrD: -0.55, ErrG: 0.12, ErrD_real: -0.10, ErrD_fake: 0.45, Time Elapsed 32.85 s
# epoch =  195
# [195/250] ErrD: -0.63, ErrG: 0.12, ErrD_real: -0.17, ErrD_fake: 0.47, Time Elapsed 32.84 s
# epoch =  196
# [196/250] ErrD: -0.52, ErrG: 0.08, ErrD_real: -0.02, ErrD_fake: 0.49, Time Elapsed 32.82 s
# epoch =  197
# [197/250] ErrD: -0.52, ErrG: 0.47, ErrD_real: -0.43, ErrD_fake: 0.09, Time Elapsed 32.79 s
# epoch =  198
# [198/250] ErrD: -0.68, ErrG: 0.57, ErrD_real: -0.50, ErrD_fake: 0.18, Time Elapsed 32.82 s
# epoch =  199
# [199/250] ErrD: -0.59, ErrG: 0.56, ErrD_real: -0.53, ErrD_fake: 0.05, Time Elapsed 32.79 s
# epoch =  200
# [200/250] ErrD: -0.57, ErrG: 0.23, ErrD_real: -0.19, ErrD_fake: 0.38, Time Elapsed 32.83 s
# epoch =  201
# [201/250] ErrD: -0.66, ErrG: 0.59, ErrD_real: -0.50, ErrD_fake: 0.16, Time Elapsed 32.75 s
# epoch =  202
# [202/250] ErrD: -0.52, ErrG: 0.55, ErrD_real: -0.49, ErrD_fake: 0.04, Time Elapsed 32.86 s
# epoch =  203
# [203/250] ErrD: -0.66, ErrG: 0.56, ErrD_real: -0.48, ErrD_fake: 0.18, Time Elapsed 32.74 s
# epoch =  204
# [204/250] ErrD: -0.56, ErrG: 0.51, ErrD_real: -0.38, ErrD_fake: 0.17, Time Elapsed 32.87 s
# epoch =  205
# [205/250] ErrD: -0.51, ErrG: 0.47, ErrD_real: -0.46, ErrD_fake: 0.05, Time Elapsed 32.73 s
# epoch =  206
# [206/250] ErrD: -0.54, ErrG: 0.50, ErrD_real: -0.40, ErrD_fake: 0.15, Time Elapsed 32.82 s
# epoch =  207
# [207/250] ErrD: -0.56, ErrG: 0.51, ErrD_real: -0.52, ErrD_fake: 0.04, Time Elapsed 32.76 s
# epoch =  208
# [208/250] ErrD: -0.38, ErrG: 0.47, ErrD_real: -0.51, ErrD_fake: -0.13, Time Elapsed 32.84 s
# epoch =  209
# [209/250] ErrD: -0.48, ErrG: 0.49, ErrD_real: -0.54, ErrD_fake: -0.06, Time Elapsed 32.78 s
# epoch =  210
# [210/250] ErrD: -0.59, ErrG: 0.51, ErrD_real: -0.41, ErrD_fake: 0.18, Time Elapsed 32.86 s
# epoch =  211
# [211/250] ErrD: -0.55, ErrG: 0.54, ErrD_real: -0.53, ErrD_fake: 0.02, Time Elapsed 32.85 s
# epoch =  212
# [212/250] ErrD: -0.53, ErrG: 0.56, ErrD_real: -0.46, ErrD_fake: 0.07, Time Elapsed 32.82 s
# epoch =  213
# [213/250] ErrD: -0.58, ErrG: 0.52, ErrD_real: -0.54, ErrD_fake: 0.04, Time Elapsed 32.81 s
# epoch =  214
# [214/250] ErrD: -0.53, ErrG: 0.56, ErrD_real: -0.48, ErrD_fake: 0.06, Time Elapsed 32.77 s
# epoch =  215
# [215/250] ErrD: -0.70, ErrG: 0.50, ErrD_real: -0.43, ErrD_fake: 0.27, Time Elapsed 32.83 s
# epoch =  216
# [216/250] ErrD: -0.68, ErrG: 0.56, ErrD_real: -0.53, ErrD_fake: 0.15, Time Elapsed 32.80 s
# epoch =  217
# [217/250] ErrD: -0.57, ErrG: 0.51, ErrD_real: -0.50, ErrD_fake: 0.06, Time Elapsed 32.81 s
# epoch =  218
# [218/250] ErrD: -0.57, ErrG: 0.47, ErrD_real: -0.48, ErrD_fake: 0.09, Time Elapsed 32.78 s
# epoch =  219
# [219/250] ErrD: -0.52, ErrG: 0.52, ErrD_real: -0.51, ErrD_fake: 0.01, Time Elapsed 32.87 s
# epoch =  220
# [220/250] ErrD: -0.60, ErrG: 0.54, ErrD_real: -0.45, ErrD_fake: 0.15, Time Elapsed 32.89 s
# epoch =  221
# [221/250] ErrD: -0.59, ErrG: 0.25, ErrD_real: -0.13, ErrD_fake: 0.46, Time Elapsed 32.79 s
# epoch =  222
# [222/250] ErrD: -0.61, ErrG: 0.28, ErrD_real: -0.28, ErrD_fake: 0.32, Time Elapsed 32.85 s
# epoch =  223
# [223/250] ErrD: -0.52, ErrG: 0.52, ErrD_real: -0.48, ErrD_fake: 0.04, Time Elapsed 32.80 s
# epoch =  224
# [224/250] ErrD: -0.65, ErrG: 0.60, ErrD_real: -0.54, ErrD_fake: 0.11, Time Elapsed 32.81 s
# epoch =  225
# [225/250] ErrD: -0.69, ErrG: 0.54, ErrD_real: -0.52, ErrD_fake: 0.17, Time Elapsed 32.90 s
# epoch =  226
# [226/250] ErrD: -0.63, ErrG: 0.53, ErrD_real: -0.45, ErrD_fake: 0.18, Time Elapsed 32.75 s
# epoch =  227
# [227/250] ErrD: -0.62, ErrG: 0.59, ErrD_real: -0.48, ErrD_fake: 0.14, Time Elapsed 32.86 s
# epoch =  228
# [228/250] ErrD: -0.74, ErrG: 0.58, ErrD_real: -0.55, ErrD_fake: 0.19, Time Elapsed 32.75 s
# epoch =  229
# [229/250] ErrD: -0.57, ErrG: 0.27, ErrD_real: -0.22, ErrD_fake: 0.35, Time Elapsed 32.79 s
# epoch =  230
# [230/250] ErrD: -0.46, ErrG: 0.04, ErrD_real: 0.01, ErrD_fake: 0.47, Time Elapsed 32.78 s
# epoch =  231
# [231/250] ErrD: -0.63, ErrG: 0.19, ErrD_real: -0.19, ErrD_fake: 0.44, Time Elapsed 32.83 s
# epoch =  232
# [232/250] ErrD: -0.71, ErrG: 0.23, ErrD_real: -0.29, ErrD_fake: 0.42, Time Elapsed 32.77 s
# epoch =  233
# [233/250] ErrD: -0.50, ErrG: 0.23, ErrD_real: -0.26, ErrD_fake: 0.25, Time Elapsed 32.84 s
# epoch =  234
# [234/250] ErrD: -0.55, ErrG: 0.18, ErrD_real: -0.19, ErrD_fake: 0.36, Time Elapsed 32.84 s
# epoch =  235
# [235/250] ErrD: -0.67, ErrG: 0.24, ErrD_real: -0.29, ErrD_fake: 0.38, Time Elapsed 32.85 s
# epoch =  236
# [236/250] ErrD: -0.59, ErrG: 0.16, ErrD_real: -0.13, ErrD_fake: 0.46, Time Elapsed 32.83 s
# epoch =  237
# [237/250] ErrD: -0.60, ErrG: 0.32, ErrD_real: -0.27, ErrD_fake: 0.33, Time Elapsed 32.74 s
# epoch =  238
# [238/250] ErrD: -0.46, ErrG: -0.02, ErrD_real: -0.01, ErrD_fake: 0.45, Time Elapsed 32.85 s
# epoch =  239
# [239/250] ErrD: -0.67, ErrG: 0.29, ErrD_real: -0.24, ErrD_fake: 0.43, Time Elapsed 32.77 s
# epoch =  240
# [240/250] ErrD: -0.61, ErrG: 0.53, ErrD_real: -0.48, ErrD_fake: 0.14, Time Elapsed 32.84 s
# epoch =  241
# [241/250] ErrD: -0.74, ErrG: 0.56, ErrD_real: -0.48, ErrD_fake: 0.26, Time Elapsed 32.76 s
# epoch =  242
# [242/250] ErrD: -0.69, ErrG: 0.30, ErrD_real: -0.30, ErrD_fake: 0.39, Time Elapsed 32.86 s
# epoch =  243
# [243/250] ErrD: -0.56, ErrG: 0.32, ErrD_real: -0.20, ErrD_fake: 0.37, Time Elapsed 32.79 s
# epoch =  244
# [244/250] ErrD: -0.44, ErrG: 0.46, ErrD_real: -0.50, ErrD_fake: -0.06, Time Elapsed 32.86 s
# epoch =  245
# [245/250] ErrD: -0.50, ErrG: 0.51, ErrD_real: -0.44, ErrD_fake: 0.06, Time Elapsed 32.83 s

# %%
dataset_test = dataset('./datasets', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(dataset_test, batch_size=batch_size, shuffle=True, num_workers=4)
